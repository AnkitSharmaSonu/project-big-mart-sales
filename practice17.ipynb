# %%
import pandas as pd
a=pd.read_csv('employees.csv')
a=a.head(100)
a
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2         Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3         Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4         Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5        Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6          Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7           NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8        Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9       Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10       Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11        Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12      Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
b={'Name':'Ankit','Age':20}
c={'Name':'Sonu','Age':20}
d=pd.DataFrame([b,c],index=['Name',''])
d
# Out:
#       Age   Name
# Name   20  Ankit
#        20   Sonu

# %%
e=pd.Series({'Name':'ankit'})
f=pd.Series(['Sonu'],index=['Name'])
e.append(f)
# Out:
# Name    ankit
# Name     Sonu
# dtype: object

# %%
a=pd.Series({'Name':'Anuhska','Age':20,'Hobbies':'Cricket'},index=['Name'])
a
# Out:
# Name    Anuhska
# dtype: object

# %%
a=dict(Name='ankit',age=20)
b=dict(Name='sonu',age=20)
c=dict(Name='rahul',age=25)
d=pd.DataFrame([a,b,c],index=['a','b','c'])
d
# Out:
#     Name  age
# a  ankit   20
# b   sonu   20
# c  rahul   25

# %%
d.drop('Name',axis=1)
d
# Out:
#     Name  age
# a  ankit   20
# b   sonu   20
# c  rahul   25

# %%
d
# Out:
#     Name  age
# a  ankit   20
# b   sonu   20
# c  rahul   25

# %%
d.loc[:,['Name','Age']]
d.loc['a','age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda setup\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# D:\Anaconda setup\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [a] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-7b7624a227c5> in <module>
#       1 d.loc[:,['Name','Age']]
# ----> 2 d.loc['a','age']
#
# ...

# %%
a=a.head()
a
# Out:
# 0    500.0
# 1    500.0
# 2    500.0
# 3    500.0
# 4    500.0
# Name: Unnamed: 8, dtype: float64

# %%
a.dropna(subset=['Unnamed: 8'])
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team, Unnamed: 8]
# Index: []

# %%
a.drop('Unnamed: 8',axis=1)
a.fillna(100,axis=1)
a.sort_values(by=['First Name'])
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 0     Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# ...

# %%
a[a['Salary'].between(10000,70000)]
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 6        Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# 7         NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 10     Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 14   Kimberly  Female  1/14/1999         7:13 AM   41426   14.543
#
#    Senior Management     Team  Unnamed: 8
# 1               True      NaN         NaN
# 6               True  Product         NaN
# 7                NaN  Finance         NaN
# 10              True      NaN         NaN
# 14              True  Finance         NaN

# %%
a['Start Date']=pd.to_datetime(a['Start Date'])
a
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 53         Alan     NaN 2014-03-03         1:28 PM   40341   17.578
# 8        Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 86        Annie     NaN 2007-09-29        12:11 AM  103495   17.290
# 87        Annie  Female 1993-01-30         2:05 AM  144887    8.276
# 29     Benjamin    Male 2005-01-26        10:06 PM   79529    7.008
# 42      Beverly  Female 1998-09-09         8:26 PM  121918   15.835
# 72        Bobby    Male 2007-05-07        10:01 AM   54043    3.833
# 75       Bonnie  Female 1991-07-02         1:27 AM  104897    5.118
# 79       Bonnie  Female 1988-11-13         3:30 PM  115814    4.990
# 12      Brandon    Male 1980-12-01         1:08 AM  112807   17.492
# 46        Bruce    Male 2009-11-28        10:47 PM  114796    6.796
# 56         Carl    Male 2006-05-03         5:55 PM  130276   16.084
# 77      Charles    Male 2004-09-14         8:13 PM  107391    1.260
# ...

# %%
a[a['Start Date'].between('1993-08-06','2005-03-04')]
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1      Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4       Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 9     Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 11      Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 14   Kimberly  Female 1999-01-14         7:13 AM   41426   14.543
#
#    Senior Management                  Team  Unnamed: 8
# 0               True             Marketing         NaN
# 1               True                   NaN         NaN
# 3               True               Finance         NaN
# 4               True       Client Services         NaN
# 9               True  Business Development         NaN
# 11              True                 Legal         NaN
# ...

# %%
a=a.sort_values('First Name')
a
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 53         Alan     NaN 2014-03-03         1:28 PM   40341   17.578
# 8        Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 86        Annie     NaN 2007-09-29        12:11 AM  103495   17.290
# 87        Annie  Female 1993-01-30         2:05 AM  144887    8.276
# 29     Benjamin    Male 2005-01-26        10:06 PM   79529    7.008
# 42      Beverly  Female 1998-09-09         8:26 PM  121918   15.835
# 72        Bobby    Male 2007-05-07        10:01 AM   54043    3.833
# 75       Bonnie  Female 1991-07-02         1:27 AM  104897    5.118
# 79       Bonnie  Female 1988-11-13         3:30 PM  115814    4.990
# 12      Brandon    Male 1980-12-01         1:08 AM  112807   17.492
# 46        Bruce    Male 2009-11-28        10:47 PM  114796    6.796
# 56         Carl    Male 2006-05-03         5:55 PM  130276   16.084
# 77      Charles    Male 2004-09-14         8:13 PM  107391    1.260
# ...

# %%
a[a['First Name'].duplicated(keep='first')]
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 87      Annie  Female 1993-01-30         2:05 AM  144887    8.276
# 79     Bonnie  Female 1988-11-13         3:30 PM  115814    4.990
# 44    Cynthia  Female 1988-11-16         6:54 PM  145146    7.482
# 88      Donna  Female 1991-11-27         1:59 PM   64088    6.155
# 9     Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 69      Irene     NaN 2015-07-14         4:31 PM  100863    4.382
# 89     Janice  Female 2016-03-12        12:40 AM   51082   11.955
# 85     Jeremy    Male 2008-02-01         8:50 AM  100238    3.887
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 37      Linda  Female 1981-10-19         8:49 PM   57427    9.557
# 63    Matthew    Male 2013-01-02        10:33 PM   35203   18.040
# 50      Nancy  Female 2000-09-23         8:05 AM   94976   13.830
# 36     Rachel  Female 2009-02-16         8:47 PM  142032   12.599
# ...

# %%
len(a)
# Out:
# 99

# %%
len(a.drop_duplicates(subset=['First Name']))
# Out:
# 76
