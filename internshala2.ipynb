# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df=pd.read_csv('chennai_house_price_prediction.csv')

df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
# ...

# %%
df['N_ROOM'].value_counts().plot(kind='hist',bins=10)
df['N_BATHROOM'].mean()
# Out:
# 1.213260135135135

# %%
temp=pd.DataFrame(index=df.columns)
temp['null count']=df.isnull().sum()
temp['object']=df.dtypes
temp['Unique Values']=df.nunique()
temp
# Out:
#                null count   object  Unique Values
# PRT_ID                  0   object           7109
# AREA                    0   object             17
# INT_SQFT                0    int64           1699
# DIST_MAINROAD           0    int64            201
# N_BEDROOM               1  float64              4
# N_BATHROOM              5  float64              2
# N_ROOM                  0    int64              5
# SALE_COND               0   object              9
# PARK_FACIL              0   object              3
# BUILDTYPE               0   object              5
# UTILITY_AVAIL           0   object              5
# STREET                  0   object              5
# MZZONE                  0   object              6
# QS_ROOMS                0  float64             31
# QS_BATHROOM             0  float64             31
# QS_BEDROOM              0  float64             31
# QS_OVERALL             48  float64            479
# COMMIS                  0    int64           7011
# ...

# %%
df['SALES_PRICE'].plot(kind='hist')

# %%
df1=pd.read_csv('train.csv')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Fare'].plot.box()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda setup\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fare'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f9e3591b9fa1> in <module>
# ----> 1 df['Fare'].plot.box()
#
# ...

# %%
(df['Sex'].value_counts()/len(df['Sex'])).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda setup\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-42c455708b0d> in <module>
# ...

# %%
df['SALES_PRICE'].plot(kind='hist',bins=50)

# %%
df['SALES_PRICE'].loc[df["SALES_PRICE"]<18000000].plot(kind='hist',bins=50)

# %% [markdown]
# # data exploration and bivariarte analysis

# %%
df.drop_duplicates()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 6     P09105    Chrompet      1167            137        1.0         1.0
# 7     P09679   Velachery      1847            176        3.0         2.0
# 8     P03377    Chrompet       771            175        1.0         1.0
# 9     P09623   Velachery      1635             74        2.0         1.0
# 10    P09540    Chrompet      1203             78        2.0         1.0
# 11    P07121    Chrompet      1054            143        1.0         1.0
# ...

# %%
df.drop_duplicates(subset=['AREA']).shape
# Out:
# (17, 19)

# %%
df.dropna()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 6     P09105    Chrompet      1167            137        1.0         1.0
# 7     P09679   Velachery      1847            176        3.0         2.0
# 8     P03377    Chrompet       771            175        1.0         1.0
# 9     P09623   Velachery      1635             74        2.0         1.0
# 10    P09540    Chrompet      1203             78        2.0         1.0
# 11    P07121    Chrompet      1054            143        1.0         1.0
# ...

# %%
df.dropna(axis=1)
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_ROOM    SALE_COND  \
# 0     P03210  Karapakkam      1004            131       3     AbNormal
# 1     P09411  Anna Nagar      1986             26       5     AbNormal
# 2     P01812       Adyar       909             70       3     AbNormal
# 3     P05346   Velachery      1855             14       5       Family
# 4     P06210  Karapakkam      1226             84       3     AbNormal
# 5     P00219    Chrompet      1220             36       4      Partial
# 6     P09105    Chrompet      1167            137       3      Partial
# 7     P09679   Velachery      1847            176       5       Family
# 8     P03377    Chrompet       771            175       2      AdjLand
# 9     P09623   Velachery      1635             74       4     AbNormal
# 10    P09540    Chrompet      1203             78       4      AdjLand
# 11    P07121    Chrompet      1054            143       3      Partial
# ...

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df['N_BATHROOM'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df['N_BEDROOM'].fillna(value=(df['N_BEDROOM'].mode()),inplace=True)
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         0
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
for i in range(0,len(df['N_BATHROOM'])):
    if pd.isnull(df['N_BATHROOM'][i])==True:
        if df['N_BATHROOM'][i]==1.0:
            df['N_BATHROOM'][i]=1.0
        else:
            df['N_BATHROOM'][i]=2.0
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         0
# N_BATHROOM        0
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
temp=(df['QS_ROOMS']+df['QS_BATHROOM']+df['QS_BEDROOM']+df['QS_OVERALL'])/3

pd.concat([df['QS_ROOMS'],df['QS_BATHROOM'],df['QS_BEDROOM'],df['QS_OVERALL'],temp],axis=1).head()
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL         0
# 0       4.0          3.9         4.9       4.330  5.710000
# 1       4.9          4.2         2.5       3.765  5.121667
# 2       4.1          3.8         2.2       3.090  4.396667
# 3       4.7          3.9         3.6       4.010  5.403333
# 4       3.0          2.5         4.1       3.290  4.296667

# %%
df['QS_OVERALL']=df.apply(lambda x: fill_na(10) if pd.isnull(x['QS_OVERALL']) else x['QS_OVERALL'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-ce3d71d747c9> in <module>
# ----> 1 df['QS_OVERALL']=df.apply(lambda x: df.fill_na(10) if pd.isnull(x['QS_OVERALL']) else x['QS_OVERALL'],axis=1)
#
# D:\Anaconda setup\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# D:\Anaconda setup\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# D:\Anaconda setup\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
# ...

# %%
temp=['PRT_ID','AREA','INT_SQFT','DIST_MAINROAD','PARK_FACIL']
for i in temp:
    print('  VALUE    COUNTS   ')
    print(df[i].value_counts())
    print(' ')
# Out:
#   VALUE    COUNTS
# P02801    1
# P06973    1
# P05940    1
# P09661    1
# P07536    1
# P05586    1
# P04819    1
# P09416    1
# P04407    1
# P04025    1
# P09027    1
# P03217    1
# P02057    1
# P08588    1
# P04712    1
# P09281    1
# P02041    1
# P01119    1
# P07062    1
# P07104    1
# P07679    1
# P00502    1
# P05803    1
# P01294    1
# P07217    1
# P07416    1
# P06152    1
# P01051    1
# P09101    1
# P00720    1
#          ..
# P07860    1
# P03260    1
# P09868    1
# P01624    1
# P02338    1
# P09804    1
# P01210    1
# P09620    1
# P00511    1
# P07825    1
# P02385    1
# P08472    1
# P01609    1
# P01374    1
# P05612    1
# P08380    1
# P09914    1
# P05283    1
# P07731    1
# P04914    1
# P01635    1
# P01679    1
# P05859    1
# P04941    1
# P09769    1
# P06339    1
# P01006    1
# P00831    1
# P03125    1
# P05809    1
# Name: PRT_ID, Length: 7109, dtype: int64
#
#   VALUE    COUNTS
# Chrompet      1681
# Karapakkam    1363
# ...

# %%
df['PARK_FACIL'].replace({'Noo':'No'},inplace=True)
