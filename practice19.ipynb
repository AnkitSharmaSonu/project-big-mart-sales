# %%
import pandas as pd
df=pd.read_csv('employees.csv',parse_dates=['Start Date','Last Login Time']).head()
df
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-05-08 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-05-08 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-05-08 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-05-08 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-05-08 16:47:00  101004    1.389
#
#   Senior Management             Team  Unnamed: 8
# 0              True        Marketing         NaN
# 1              True              NaN         NaN
# 2             False          Finance         NaN
# 3              True          Finance         NaN
# 4              True  Client Services         NaN

# %%
df.drop('Unnamed: 8',axis=1,inplace=True)

# %%
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
# First Name           5 non-null object
# Gender               5 non-null category
# Start Date           5 non-null datetime64[ns]
# Last Login Time      5 non-null datetime64[ns]
# Salary               5 non-null int64
# Bonus %              5 non-null float64
# Senior Management    5 non-null bool
# Team                 4 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 426.0+ bytes

# %%
df=pd.read_csv('james bond.csv')
df.drop('Unnamed: 7',axis=1,inplace=True)
df.set_index(['Film'],inplace=True)
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
df.loc[:,'Actor']
# Out:
# Film
# Dr. No                               Sean Connery
# From Russia with Love                Sean Connery
# Goldfinger                           Sean Connery
# Thunderball                          Sean Connery
# Casino Royale                         David Niven
# You Only Live Twice                  Sean Connery
# On Her Majesty's Secret Service    George Lazenby
# Diamonds Are Forever                 Sean Connery
# Live and Let Die                      Roger Moore
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# Moonraker                             Roger Moore
# For Your Eyes Only                    Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# A View to a Kill                      Roger Moore
# The Living Daylights               Timothy Dalton
# Licence to Kill                    Timothy Dalton
# GoldenEye                          Pierce Brosnan
# ...

# %%
df.iloc[4]
# Out:
# Year                        1967
# Actor                David Niven
# Director              Ken Hughes
# Box Office                   315
# Budget                        85
# Bond Actor Salary            NaN
# Name: Casino Royale, dtype: object

# %%
df.ix[4]
# Out:
# D:\Anaconda setup\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                        1967
# Actor                David Niven
# Director              Ken Hughes
# Box Office                   315
# Budget                        85
# Bond Actor Salary            NaN
# Name: Casino Royale, dtype: object

# %%
df.ix[['Dr. No','Gol']]
# Out:
# D:\Anaconda setup\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# D:\Anaconda setup\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#           Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No  1962.0  Sean Connery  Terence Young       448.8     7.0
# Gol        NaN           NaN            NaN         NaN     NaN
#
#         Bond Actor Salary
# Film
# ...

# %%
df.ix[1,'Year']
# Out:
# D:\Anaconda setup\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 1963

# %%
mask=df['Actor']=='Sean Connery'
df.ix[mask,'Actor']='Sir Sean Connery'
df.head()
# Out:
# D:\Anaconda setup\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                        Year             Actor       Director  Box Office  \
# Film
# Dr. No                 1962  Sir Sean Connery  Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery  Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery   Guy Hamilton       820.4
# Thunderball            1965  Sir Sean Connery  Terence Young       848.1
# Casino Royale          1967       David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# ...

# %%
df.rename(columns={'Year':'Years'},index={'Dr. No':'kl'})
# Out:
#                                  Years             Actor            Director  \
# Film
# kl                                1962  Sir Sean Connery       Terence Young
# From Russia with Love             1963  Sir Sean Connery       Terence Young
# Goldfinger                        1964  Sir Sean Connery        Guy Hamilton
# Thunderball                       1965  Sir Sean Connery       Terence Young
# Casino Royale                     1967       David Niven          Ken Hughes
# You Only Live Twice               1967  Sir Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service   1969    George Lazenby       Peter R. Hunt
# Diamonds Are Forever              1971  Sir Sean Connery        Guy Hamilton
# Live and Let Die                  1973       Roger Moore        Guy Hamilton
# The Man with the Golden Gun       1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me              1977       Roger Moore       Lewis Gilbert
# ...

# %%
df.columns=[i.replace(' ','') for i in df.columns]
df
# Out:
#                                  Year             Actor            Director  \
# Film
# Dr. No                           1962  Sir Sean Connery       Terence Young
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Thunderball                      1965  Sir Sean Connery       Terence Young
# Casino Royale                    1967       David Niven          Ken Hughes
# You Only Live Twice              1967  Sir Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969    George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977       Roger Moore       Lewis Gilbert
# ...

# %%
df.query('Year == 2008 or Actor== "Pierce Brosnan" ')
# Out:
#                          Year           Actor            Director  BoxOffice  \
# Film
# GoldenEye                1995  Pierce Brosnan     Martin Campbell      518.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode      463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted      439.5
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori      465.4
# Quantum of Solace        2008    Daniel Craig        Marc Forster      514.2
#
#                          Budget  BondActorSalary
# Film
# GoldenEye                  76.9              5.1
# Tomorrow Never Dies       133.9             10.0
# The World Is Not Enough   158.3             13.5
# Die Another Day           154.2             17.9
# Quantum of Solace         181.4              8.1

# %%
df.query('Actor  in ["Pierce Brosnan","Daniel Craig"]')
# Out:
#                          Year           Actor            Director  BoxOffice  \
# Film
# GoldenEye                1995  Pierce Brosnan     Martin Campbell      518.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode      463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted      439.5
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori      465.4
# Casino Royale            2006    Daniel Craig     Martin Campbell      581.5
# Quantum of Solace        2008    Daniel Craig        Marc Forster      514.2
# Skyfall                  2012    Daniel Craig          Sam Mendes      943.5
# Spectre                  2015    Daniel Craig          Sam Mendes      726.7
#
#                          Budget  BondActorSalary
# Film
# GoldenEye                  76.9              5.1
# Tomorrow Never Dies       133.9             10.0
# The World Is Not Enough   158.3             13.5
# Die Another Day           154.2             17.9
# ...
