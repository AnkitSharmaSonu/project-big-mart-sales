# %%
import pandas as pd
a=pd.read_csv('data_python.csv')
a.iloc[:,3:5]
# Out:
#     Dependents     Education
# 0            0      Graduate
# 1            1      Graduate
# 2            0      Graduate
# 3            0  Not Graduate
# 4            0      Graduate
# 5            2      Graduate
# 6            0  Not Graduate
# 7           3+      Graduate
# 8            2      Graduate
# 9            1      Graduate
# 10           2      Graduate
# 11           2      Graduate
# 12           2      Graduate
# 13           0      Graduate
# 14           2      Graduate
# 15           0      Graduate
# 16           1  Not Graduate
# 17           0      Graduate
# 18           0  Not Graduate
# 19           0      Graduate
# 20           0  Not Graduate
# 21           1      Graduate
# 22           0  Not Graduate
# 23           2  Not Graduate
# 24           1      Graduate
# 25           0      Graduate
# 26           0      Graduate
# 27           2  Not Graduate
# 28           0  Not Graduate
# 29           2      Graduate
# ..         ...           ...
# ...
