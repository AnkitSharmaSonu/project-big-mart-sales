# %%
import pandas as pd
a=pd.read_csv('file8.csv',squeeze=True)

a.value_counts(ascending=False)
# Out:
# ankit      100    2
# golu       200    1
# rahul      300    1
# anushka    300    1
# sonu       200    1
# golu       600    1
# Name: NAME       MARKS, dtype: int64

# %%
a=pd.read_csv('file7.csv',squeeze=True)
a
# Out:
# 0    110
# 1     22
# 2     33
# 3     11
# 4     33
# 5     77
# 6     44
# 7     77
# 8     44
# Name: marks, dtype: int64

# %%
def fun(x):
    if x<=50:
        print('fair')
    elif x>=50 and x<=75:
        print('good')
    else:
        print('excellent')
a.apply(fun)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-6eaf8a906f02> in <module>
#       6     else:
#       7         print('excellent')
# ----> 8 a.apply(fun)
#
# D:\Anaconda setup\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-88-6eaf8a906f02> in fun(x)
#       1 def fun(x):
# ----> 2     if x<=50:
#       3         print('fair')
#       4     elif x>=50 and x<=75:
#       5         print('good')
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# # Dataframes

# %%
a=pd.read_csv('nb.csv')
a
# Out:
#      Unnamed: 0                     Name                    Team  Number  \
# 0           NaN            Avery Bradley          Boston Celtics       0
# 1           NaN              Jae Crowder          Boston Celtics      99
# 2           NaN             John Holland          Boston Celtics      30
# 3           NaN              R.J. Hunter          Boston Celtics      28
# 4           NaN            Jonas Jerebko          Boston Celtics       8
# 5           NaN             Amir Johnson          Boston Celtics      90
# 6           NaN            Jordan Mickey          Boston Celtics      55
# 7           NaN             Kelly Olynyk          Boston Celtics      41
# 8           NaN             Terry Rozier          Boston Celtics      12
# 9           NaN             Marcus Smart          Boston Celtics      36
# 10          NaN          Jared Sullinger          Boston Celtics       7
# 11          NaN            Isaiah Thomas          Boston Celtics       4
# ...

# %%
b=a[['Name','Team','Number','Position','Age','Height','Weight','College',"Salary"]].copy()
b.head(10)
b.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz      41       PF   20  10-Jun     234  Kentucky
# 453  Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24   1-Jun     179       NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256       NaN
# 456   Jeff Withey  Utah Jazz      24        C   26  Jul-00     231    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
b.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
b.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
b.info
# Out:
# <bound method DataFrame.info of                         Name                    Team  Number Position  Age  \
# 0              Avery Bradley          Boston Celtics       0       PG   25
# 1                Jae Crowder          Boston Celtics      99       SF   25
# 2               John Holland          Boston Celtics      30       SG   27
# 3                R.J. Hunter          Boston Celtics      28       SG   22
# 4              Jonas Jerebko          Boston Celtics       8       PF   29
# 5               Amir Johnson          Boston Celtics      90       PF   29
# 6              Jordan Mickey          Boston Celtics      55       PF   21
# 7               Kelly Olynyk          Boston Celtics      41        C   25
# 8               Terry Rozier          Boston Celtics      12       PG   22
# 9               Marcus Smart          Boston Celtics      36       PG   22
# 10           Jared Sullinger          Boston Celtics       7        C   24
# ...

# %%
b.get_dtype_counts()
# Out:
# object     5
# int64      3
# float64    1
# dtype: int64

# %%
l=['ankit','sharma']
l1=['anushka','tiwari']
l.extend(l1)
l
# Out:
# ['ankit', 'sharma', 'anushka', 'tiwari']

# %%
p=pd.read_csv('nba1.csv').head()
p
# Out:
#        Date  New York  Los Angeles  Miami  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  1/1/2016     985.0        122.0  499.0         NaN         NaN         NaN
# 1  1/2/2016     738.0        788.0  534.0         NaN         NaN         NaN
# 2  1/3/2016      14.0         20.0  933.0         NaN         NaN         NaN
# 3  1/4/2016     730.0        904.0  885.0         NaN         NaN         NaN
# 4  1/5/2016     114.0         71.0  253.0         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
p.sum()
# Out:
# Date           1/1/20161/2/20161/3/20161/4/20161/5/2016
# New York                                           2581
# Los Angeles                                        1905
# Ank                 CricketCricketCricketCricketCricket
# Ankita                             KucjKucjKucjKucjKucj
# Ankit                              KucjKucjKucjKucjKucj
# Miami                                              3104
# Unnamed: 4                                            0
# Unnamed: 5                                            0
# Unnamed: 6                                            0
# Unnamed: 7                                            0
# Unnamed: 8                                            0
# Songs          ShoppingShoppingShoppingShoppingShopping
# dtype: object

# %%
p.sum(axis=1)
# Out:
# 0    1606.0
# 1    2060.0
# 2     967.0
# 3    2519.0
# 4     438.0
# dtype: float64

# %%
p['Songs']='Shopping'
p.insert(loc=3,column='Ank',value="Cricket")
p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-aae2c0a8451f> in <module>
#       1 p['Songs']='Shopping'
# ----> 2 p.insert(loc=3,column='Ank',value="Cricket")
#       3 p
#
# D:\Anaconda setup\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
# -> 3222                           allow_duplicates=allow_duplicates)
#    3223
#    3224     def assign(self, **kwargs):
#
# D:\Anaconda setup\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# ...

# %%
x=pd.read_csv('nb.csv').head()
x
# Out:
#    Unnamed: 0           Name            Team  Number Position  Age  Height  \
# 0         NaN  Avery Bradley  Boston Celtics       0       PG   25   2-Jun
# 1         NaN    Jae Crowder  Boston Celtics      99       SF   25   6-Jun
# 2         NaN   John Holland  Boston Celtics      30       SG   27   5-Jun
# 3         NaN    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun
# 4         NaN  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
x['Salary']+5
x['kl']=x['Salary']*10
x
# Out:
#    Unnamed: 0           Name            Team  Number Position  Age  Height  \
# 0         NaN  Avery Bradley  Boston Celtics       0       PG   25   2-Jun
# 1         NaN    Jae Crowder  Boston Celtics      99       SF   25   6-Jun
# 2         NaN   John Holland  Boston Celtics      30       SG   27   5-Jun
# 3         NaN    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun
# 4         NaN  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun
#
#    Weight            College     Salary          kl
# 0     180              Texas  7730337.0  77303370.0
# 1     235          Marquette  6796117.0  67961170.0
# 2     205  Boston University        NaN         NaN
# 3     185      Georgia State  1148640.0  11486400.0
# 4     231                NaN  5000000.0  50000000.0

# %%
z=pd.read_csv('nb.csv').head(20)
z.dropna(how='all')
z.dropna(axis=1)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25   2-Jun
# 1               Jae Crowder  Boston Celtics      99       SF   25   6-Jun
# 2              John Holland  Boston Celtics      30       SG   27   5-Jun
# 3               R.J. Hunter  Boston Celtics      28       SG   22   5-Jun
# 4             Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun
# 5              Amir Johnson  Boston Celtics      90       PF   29   9-Jun
# 6             Jordan Mickey  Boston Celtics      55       PF   21   8-Jun
# 7              Kelly Olynyk  Boston Celtics      41        C   25  Jul-00
# 8              Terry Rozier  Boston Celtics      12       PG   22   2-Jun
# 9              Marcus Smart  Boston Celtics      36       PG   22   4-Jun
# 10          Jared Sullinger  Boston Celtics       7        C   24   9-Jun
# 11            Isaiah Thomas  Boston Celtics       4       PG   27   9-May
# ...

# %%
for i in '':
  print(i)

# %%
for i in range 2.0 :
    print(i)
# Out:
#   File "<ipython-input-189-0b5804b8b6d4>", line 1
#     for i in range 2.0 :
#                      ^
# SyntaxError: invalid syntax
