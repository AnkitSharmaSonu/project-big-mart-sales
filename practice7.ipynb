# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.linspace(0.0,5.0)
a1=np.linspace(0.0,2.0)
b=np.cos(2*np.pi*a)*np.exp(-a)
b1=np.cos(2*np.pi*a1)*np.exp(a1)
l=[1,2,3,4]
l1=[5,6,7,8]
plt.subplot(2,1,1)
plt.plot(a,b,'+')
plt.grid()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('linear graph')
plt.subplot(2,1,2)
plt.plot(a1,b1,'*')
plt.xlabel('x axis')
plt.ylabel('y-axis')
plt.show()

# %%
l=[1,2,3,4]
l1=iter(l)
print(next(l1))
print()
# Out:
# 1

# %%
l1=[1,2,3,4]
l=[5,6,7,8]
a=['a','b','c','d']
plt.bar(l1,l,width=0.5,tick_label=a)

plt.show()

# %%
range=(10,30)
age=[20,30,100,22,33,23,15,38,42,43,26,16,30]
bins=10
plt.hist(age,bins,range,color='red',rwidth=0.5)
plt.show()

# %%
x=[1,2,34,4,5,6,7,78,9,10]

y=[11,22,33,44,55,66,7,78,99,100]
l=[1,2,3,4]
l1=[5,6,7,8]


plt.scatter(l,l1,label="stars",color="red",marker="*" ,s=200)
plt.legend()
plt.show()

# %%
activities=['eat','sleep','work','today']
l=[1,2,3,4]

plt.pie(l,labels=activities,colors=['r','b','g','m'],startangle=90,shadow=True,explode=(0,0.2,0.1,0),autopct='%1.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# # matplotlib practice mode till pie

# %%
print(l)
l1=[5,6,7,8]
print(l1)
# Out:
# [1, 2, 3, 4]
# [5, 6, 7, 8]

# %%
import numpy as np
import matplotlib.pyplot as plt
l=np.arange(1,2,0.1)
l1=np.arange(2,3,0.1)
l2=np.arange(3,4,0.1)
l3=np.arange(4,5,0.1)
plt.subplot(1,2,1)
plt.plot(l,l1)
plt.subplot(1,2,2)
plt.plot(l2,l3)
plt.show()

# %%
x=np.arange(0,2*np.pi,0.1)
x1=np.cos(x)
x2=np.sin(x)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('linear graph')
plt.plot(x,x1)
plt.plot(x,x2)
plt.show()

# %%
with open('ankit.txt','r') as f:
    f=f.reader()
    x=[]
    x1=[]
    for i in f:
        print(i)
        x,x1=i.split(',')
print(x)
print(x1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-071a6aae6b46> in <module>
#       1 with open('ankit.txt','r') as f:
# ----> 2     f=f.reader()
#       3     x=[]
#       4     x1=[]
#       5     for i in f:
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'reader'

# %%
from csv import reader
x=[]
x1=[]

with open('file2.csv','r') as f:
    af=reader(f)
    for i in af:
        
        x.append(i[0])
        x1.append(i[1])
print(x)
print(x1)
plt.plot(x,x1,label='ANKIT',color='green')
plt.legend()
plt.show()
# Out:
# ['10', '30', '50', '70', '90']
# ['20', '40', '60', '80', '100']

# %%
a1='ankit,sharma'
a,b=a1.split(',')
print(a1
     )
# Out:
# ankit,sharma

# %%
import pandas as pd
