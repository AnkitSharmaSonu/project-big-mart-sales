# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv('employees.csv')
a.head()
a=a.set_index('First Name')
a.head()
# Out:
#             Gender Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male   8/6/1993        12:42 PM   97308    6.945
# Thomas        Male  3/31/1996         6:53 AM   61933    4.170
# Maria       Female  4/23/1993        11:17 AM  130590   11.858
# Jerry         Male   3/4/2005         1:00 PM  138705    9.340
# Larry         Male  1/24/1998         4:47 PM  101004    1.389
#
#            Senior Management             Team  Unnamed: 8
# First Name
# Douglas                 True        Marketing         NaN
# Thomas                  True              NaN         NaN
# Maria                  False          Finance         NaN
# Jerry                   True          Finance         NaN
# Larry                   True  Client Services         NaN

# %%
b=a.groupby('First Name')['Salary']
b.first()
# Out:
# First Name
# Alan            40341
# Angela          95570
# Annie          103495
# Benjamin        79529
# Beverly        121918
# Bobby           54043
# Bonnie         104897
# Brandon        112807
# Bruce          114796
# Carl           130276
# Charles        107391
# Chris          113590
# Christina      118780
# Christine       66582
# Christopher     47369
# Clarence        93581
# Craig           37598
# Cynthia        145146
# Denise         106862
# Dennis         115163
# Diana          132940
# Donna           81014
# Doris           83072
# Douglas         97308
# Frances        139852
# Gary           109831
# Gerald         137126
# Harry          130620
# Heather         43026
# Henry           64715
#                 ...
# Kimberly        41426
# Larry          101004
# Laura          140371
# Lillian         59414
# Linda           57427
# Lois            64714
# Louise          63241
# Margaret       131604
# Maria          130590
# Marilyn         73524
# ...

# %%
df=pd.read_csv('train_bm.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
from sklearn.utils import shuffle
data=shuffle(data,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-8434f3db58f2> in <module>
#       1 from sklearn.utils import shuffle
# ----> 2 data=shuffle(data,random_state=42)
#       3 data
#
# NameError: name 'data' is not defined
