# %%
from practice6 import add
add(1,2)
# Out:
# 3

# %%
print('my name is {} sharma'.format('ankit'))
# Out:
# my name is ankit sharma

# %%
l=[1,2,3,4,5]
x=iter(l)
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-30-5a3da0fca720> in <module>
#       6 print(next(x))
#       7 print(next(x))
# ----> 8 print(next(x))
#       9 print(next(x))
#
# StopIteration:

# %%
a=dict(name='ankit',age=20)
a
n=input()
if n in a.values():
    print('yes')
# Out:
# name

# %%
import numpy as p
p.zeros((2,2))
p.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
import matplotlib.pyplot as plt
l=[1,2,3,4]
l1=[5,6,7,8]
plt.plot(l,l1,'*')
plt.grid()
plt.xlabel('this is x axis')
plt.ylabel('this is y axis')
plt.title('normal graph')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.arange(0.0,2.0,0.1)
b=1+np.cos(2*np.pi*a)
plt.plot(a,b)
plt.grid()
plt.show()
