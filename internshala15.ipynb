# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('No2 dataset.csv')
df.head()
# Out:
#              Date_Time  NO2(GT)
# 0  10/03/2004 18.00.00      166
# 1  10/03/2004 19.00.00     1174
# 2  10/03/2004 20.00.00      131
# 3  10/03/2004 21.00.00      172
# 4  10/03/2004 22.00.00      131

# %%
df['Date_Time']=pd.to_datetime(df['Date_Time'],format='%d/%m/%Y %H.%M.%S')

# %%
df['Date_Time'].dt.hour.head()
# Out:
# 0    18
# 1    19
# 2    20
# 3    21
# 4    22
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.minute.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.second.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.week.head()
# Out:
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.dayofweek.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.weekday_name.head()
# Out:
# 0    Wednesday
# 1    Wednesday
# 2    Wednesday
# 3    Wednesday
# 4    Wednesday
# Name: Date_Time, dtype: object

# %%
df['Date_Time'].dt.month.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Date_Time, dtype: int64

# %%
df['Date_Time'].dt.is_month_end.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Date_Time, dtype: bool

# %%
a=pd.DataFrame({'hours':df['Date_Time'].dt.hour,
                'dayofweek':df['Date_Time'].dt.dayofweek,
                'weekday_name':df['Date_Time'].dt.weekday_name} ) 
a
# Out:
#       hours  dayofweek weekday_name
# 0        18          2    Wednesday
# 1        19          2    Wednesday
# 2        20          2    Wednesday
# 3        21          2    Wednesday
# 4        22          2    Wednesday
# 5        23          2    Wednesday
# 6         0          3     Thursday
# 7         1          3     Thursday
# 8         2          3     Thursday
# 9         3          3     Thursday
# 10        4          3     Thursday
# 11        5          3     Thursday
# 12        6          3     Thursday
# 13        7          3     Thursday
# 14        8          3     Thursday
# 15        9          3     Thursday
# 16       10          3     Thursday
# 17       11          3     Thursday
# 18       12          3     Thursday
# 19       13          3     Thursday
# 20       14          3     Thursday
# 21       15          3     Thursday
# 22       16          3     Thursday
# 23       17          3     Thursday
# 24       18          3     Thursday
# ...

# %%
y=pd.read_csv('agent_classification.csv')
y.head()
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1000001      842001                4/16/2007            844120.0
# 1  FIN1000002      842001                4/16/2007            844111.0
# 2  FIN1000003      800001                4/16/2007            844101.0
# 3  FIN1000004      814112                4/16/2007            814112.0
# 4  FIN1000005      814112                4/16/2007            815351.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M          12/19/1971                        M
# 1                M           2/17/1983                        S
# 2                M           1/16/1966                        M
# 3                M            2/3/1988                        S
# 4                M            7/4/1985                        M
#
#   Applicant_Occupation Applicant_Qualification Manager_DOJ        ...         \
# 0               Others                Graduate  11/10/2005        ...
# ...

# %%
y['Application_Receipt_Date']=pd.to_datetime(y['Application_Receipt_Date'],format='%m/%d/%Y')
y['Applicant_BirthDate']=pd.to_datetime(y['Applicant_BirthDate'],format='%m/%d/%Y')
(y['Application_Receipt_Date'][0]-y['Applicant_BirthDate'][0]).days
# Out:
# 12902

# %%
y['sub']=y.apply(lambda x: (x['Application_Receipt_Date']-x['Applicant_BirthDate']).days,axis=1)
y.head()
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1000001      842001               2007-04-16            844120.0
# 1  FIN1000002      842001               2007-04-16            844111.0
# 2  FIN1000003      800001               2007-04-16            844101.0
# 3  FIN1000004      814112               2007-04-16            814112.0
# 4  FIN1000005      814112               2007-04-16            815351.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M          1971-12-19                        M
# 1                M          1983-02-17                        S
# 2                M          1966-01-16                        M
# 3                M          1988-02-03                        S
# 4                M          1985-07-04                        M
#
#   Applicant_Occupation Applicant_Qualification Manager_DOJ   ...     \
# 0               Others                Graduate  11/10/2005   ...
# ...
